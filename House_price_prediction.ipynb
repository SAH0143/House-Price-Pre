# %% [markdown]
# <a href="https://colab.research.google.com/github/SAH0143/House-Price-Pre/blob/main/House_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/house_price/IowaHousingPrices.csv')
df.head()
# Out:
#    SquareFeet  SalePrice
# 0        1710     208500
# 1        1262     181500
# 2        1786     223500
# 3        1717     140000
# 4        2198     250000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['SquareFeet'].plot(kind='hist', bins=20, title='SquareFeet')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['SalePrice'].plot(kind='hist', bins=20, title='SalePrice')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
squareFeet = df[['SquareFeet']].values
salePrice = df[['SalePrice']].values

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(1,input_shape =(1,)))
model.compile(keras.optimizers.Adam(learning_rate=1),'mean_squared_error')
model.fit(squareFeet, salePrice, epochs=30, batch_size =10)
# Out:
# Epoch 1/30
# 146/146 [==============================] - 1s 2ms/step - loss: 15209554944.0000
# Epoch 2/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3426030592.0000
# Epoch 3/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3183808256.0000
# Epoch 4/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3192932864.0000
# Epoch 5/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3192893184.0000
# Epoch 6/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3193232896.0000
# Epoch 7/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3194816768.0000
# Epoch 8/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3193770752.0000
# Epoch 9/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3202493696.0000
# Epoch 10/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3216302592.0000
# Epoch 11/30
# ...

# %%
ax = df.plot(kind='scatter', x='SquareFeet', y='SalePrice')
plt.title('Housing Prices and Square Footage of Gaurav Homes')
y_pred = model.predict(squareFeet)
plt.plot(squareFeet, y_pred, color='red')

plt.show()
# Out:
# 46/46 [==============================] - 0s 5ms/step
